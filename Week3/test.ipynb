# %%
import sys

print(f"Python path: {sys.executable}")

# Test a package from requirements.txt

import numpy as np

print(f"Numpy version: {np.__version__}")
# Out:
# Python path: d:\Python Projects\DSA-Hybrid-Moringa\Week3\essentials_env\Scripts\python.exe
# Numpy version: 2.2.6
