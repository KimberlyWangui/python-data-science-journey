# %%
import ride
from ride import Ride

# %%
import driver
from driver import Driver

# %%
class Passenger:
    pass

# %%
meryl = Passenger()
daniel = Passenger()

print(meryl)
print(daniel)

# %%
flatiron_taxi = Driver()
print(flatiron_taxi)

# %%
ride_to_school = Ride()
ride_home = Ride()

print(ride_to_school)
print(ride_home)
