# %% [markdown]
# # PROBABILITY AND DISTRIBUTIONS

# %% [markdown]
# ### Universal Sets
# It is a set that contains everythin(outcomes / values) <br>
# - Example: Rolling a dice
# > S = {1, 2, 3, 4, 5, 6}
# - Tossing a coin
# > S = {H, T}
