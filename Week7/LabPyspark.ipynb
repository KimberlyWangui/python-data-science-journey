# %%
from pyspark import SparkConf, SparkContext

# %%
# Create a SparkConf object
conf = SparkConf().setAppName("PySparkBasicsDemo").setMaster("local[*]")  # "local[*]" runs Spark locally using all cores

# Create a SparkContext
sc = SparkContext(conf=conf)

# %%
# Application Name
print("Application Name:", sc.appName)

# Master URL
print("Master URL:", sc.master)

# SparkConf - All configurations
print("SparkConf Settings:", sc.getConf().getAll())

# Default Parallelism (number of partitions)
print("Default Parallelism:", sc.defaultParallelism)

# Default Minimum Partitions for RDDs
print("Default Minimum Partitions:", sc.defaultMinPartitions)

# Spark Home Directory (if set)
print("Spark Home:", sc.sparkHome)

# User Running the Spark Application
print("Spark User:", sc.sparkUser())

# Spark and Python Versions
print("Spark Version:", sc.version)
print("Python Version:", sc.pythonVer)

# Registered RDDs (shows active RDDs)
print("Registered RDDs:", sc._jsc.getPersistentRDDs())

# Available Resources (CPU, Memory, etc.)
print("Available Resources:", sc._jsc.sc().resources())
# Out:
# Application Name: PySparkBasicsDemo
# Master URL: local[*]
# SparkConf Settings: [('spark.driver.host', 'host.docker.internal'), ('spark.driver.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false'), ('spark.app.name', 'PySparkBasicsDemo'), ('spark.executor.id', 'driver'), ('spark.app.submitTime', '1778349475809'), ('spark.driver.port', '62812'), ('spark.app.id', 'local-1778349479435'), ('spark.rdd.compress', 'True'), ('spark.executor.extraJavaOptions', '-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false'), ('spark.serializer.objectStreamReset', '100'), ('spark.master', 'local[*]'), ('spark.submit.pyFiles', ''), ('spark.app.startTime', '1778349476210'), ('spark.submit.deployMode', 'client'), ('spark.ui.showConsoleProgress', 'true')]
# Default Parallelism: 12
# Default Minimum Partitions: 2
# Spark Home: None
# Spark User: 25473
# Spark Version: 3.5.3
# Python Version: 3.11
# Registered RDDs: {}
# Available Resources: Map()

# %%
# Modify Log Level
sc.setLogLevel("WARN")  # Set log level to "WARN"

# Retrieve Current Log Level
print("Current Log Level:", sc.getConf().get("spark.logConf"))
# Out:
# Current Log Level: None

# %%
# Create a simple RDD from a range of numbers
rdd = sc.parallelize(range(10))

# Perform an action - sum the elements
sum_result = rdd.sum()
print("Sum of RDD Elements:", sum_result)
# Out:
# Sum of RDD Elements: 45

# %%
# Stop the SparkContext
sc.stop()
